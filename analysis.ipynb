# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tourism_data = pd.read_csv("Tourism_In_India_Statistics.csv")

# %%
tourism_data.columns
# Out:
# Index(['State/UT', '2016 - Domestic', '2016 - Foreign', '2017 - Domestic',
#        '2017 - Foreign', 'Growth Rate - Domestic', 'Growth Rate - Foreign'],
#       dtype='object')

# %%
tourism_data.head()
# Out:
#                     State/UT  2016 - Domestic  2016 - Foreign  \
# 0  Andaman & Nicobar Islands           384552           15466
# 1             Andhra Pradesh        153163354          341764
# 2          Arunachal Pradesh           385875            6598
# 3                      Assam          5160599           19456
# 4                      Bihar         28516127         1010531
#
#    2017 - Domestic  2017 - Foreign  Growth Rate - Domestic  \
# 0           471919           15313                    22.7
# 1        165433898          271362                     8.0
# 2           444005            7147                    15.1
# 3          6052667           21760                    17.3
# 4         32414063         1082705                    13.7
#
#    Growth Rate - Foreign
# 0                   -1.0
# 1                  -20.6
# 2                    8.3
# 3                   11.8
# 4                    7.1

# %%
tourism_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State/UT                37 non-null     object
#  1   2016 - Domestic         37 non-null     int64
#  2   2016 - Foreign          37 non-null     int64
#  3   2017 - Domestic         37 non-null     int64
#  4   2017 - Foreign          37 non-null     int64
#  5   Growth Rate - Domestic  37 non-null     float64
#  6   Growth Rate - Foreign   37 non-null     float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 2.1+ KB

# %%
tourism_data.shape
# Out:
# (37, 7)

# %%
tourism_data.describe(include=
# Out:
#        2016 - Domestic  2016 - Foreign  2017 - Domestic  2017 - Foreign  \
# count     3.700000e+01    3.700000e+01     3.700000e+01    3.700000e+01
# mean      8.731830e+07    1.335919e+06     8.932353e+07    1.453332e+06
# std       2.683344e+08    4.129228e+06     2.745973e+08    4.486874e+06
# min       8.716000e+03    7.530000e+02     6.620000e+03    1.027000e+03
# 25%       8.262010e+05    1.546600e+04     9.908560e+05    1.531300e+04
# 50%       1.317254e+07    1.665700e+05     1.423547e+07    1.709870e+05
# 75%       4.225291e+07    6.806830e+05     4.834312e+07    1.082705e+06
# max       1.615389e+09    2.471450e+07     1.652485e+09    2.688664e+07
#
#        Growth Rate - Domestic  Growth Rate - Foreign
# count               37.000000              37.000000
# mean                 8.556757              12.645946
# std                 21.235800              24.670220
# min                -48.100000             -41.600000
# ...

# %%
tourism_data.isnull().any()
# Out:
# State/UT                  False
# 2016 - Domestic           False
# 2016 - Foreign            False
# 2017 - Domestic           False
# 2017 - Foreign            False
# Growth Rate - Domestic    False
# Growth Rate - Foreign     False
# dtype: bool

# %%
tourism_data["2016 - Domestic"].mean()
# Out:
# 87318303.72972973

# %%
tourism_data["2017 - Domestic"].mean()
# Out:
# 89323532.8108108

# %%
tourism_data["2016 - Domestic"].max()
# Out:
# 1615388619

# %%
tourism_data["2017 - Domestic"].mean()
# Out:
# 89323532.8108108

# %%
tourism_data["2017 - Domestic"].plot(kind='hist', figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
tourism_data["State/UT"].value_counts()
# Out:
# Andaman & Nicobar Islands    1
# Madhya Pradesh               1
# Manipur                      1
# Meghalaya                    1
# Mizoram                      1
# Nagaland                     1
# Odisha                       1
# Puducherry                   1
# Punjab                       1
# Rajasthan                    1
# Sikkim                       1
# Tamil Nadu                   1
# Telangana                    1
# Tripura                      1
# Uttar Pradesh                1
# Uttarakhand                  1
# West Bengal                  1
# Maharashtra                  1
# Lakshadweep                  1
# Andhra Pradesh               1
# Kerala                       1
# Arunachal Pradesh            1
# Assam                        1
# Bihar                        1
# Chandigarh                   1
# Chhattisgarh                 1
# Dadra & Nagar Haveli         1
# Daman & Diu                  1
# Delhi                        1
# Goa                          1
# ...

# %%
corelation = tourism_data.corr()
corelation
# Out:
#                         2016 - Domestic  2016 - Foreign  2017 - Domestic  \
# 2016 - Domestic                1.000000        0.977442         0.998411
# 2016 - Foreign                 0.977442        1.000000         0.977855
# 2017 - Domestic                0.998411        0.977855         1.000000
# 2017 - Foreign                 0.976842        0.999782         0.977372
# Growth Rate - Domestic        -0.098451       -0.072849        -0.067191
# Growth Rate - Foreign         -0.057606       -0.052028        -0.055457
#
#                         2017 - Foreign  Growth Rate - Domestic  \
# 2016 - Domestic               0.976842               -0.098451
# 2016 - Foreign                0.999782               -0.072849
# 2017 - Domestic               0.977372               -0.067191
# 2017 - Foreign                1.000000               -0.071062
# Growth Rate - Domestic       -0.071062                1.000000
# Growth Rate - Foreign        -0.039992               -0.009051
#
# ...

# %%
fig = plt.figure(figsize=(14,6))
plt.matshow(corelation, cmap="RdBu", fignum=fig.number)
plt.xticks(range(len(corelation.columns)), corelation.columns, rotation="vertical")
plt.yticks(range(len(corelation.columns)), corelation.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x214709a4e88>,
# ...
#  [Text(0, 0, '2016 - Domestic'),
#   Text(0, 1, '2016 - Foreign'),
#   Text(0, 2, '2017 - Domestic'),
#   Text(0, 3, '2017 - Foreign'),
#   Text(0, 4, 'Growth Rate - Domestic'),
#   Text(0, 5, 'Growth Rate - Foreign')])

# %%
tourims_data.plot(kind="line", x="State/UT", y="2016 - Domestic", figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='State/UT'>

# %%
tourims_data.plot(kind="line", x="State/UT", y="2017 - Domestic", figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='State/UT'>

# %%
sns.boxplot(x="2016 - Domestic", data=tourims_data)
# Out:
# <AxesSubplot:xlabel='2016 - Domestic'>

# %%
sns.boxplot(x="2017 - Domestic", data=tourims_data)
# Out:
# <AxesSubplot:xlabel='2017 - Domestic'>
